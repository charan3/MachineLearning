# %% [markdown]
# <a href="https://colab.research.google.com/github/charan3/MachineLearning/blob/master/SupervisedLearning/BikeSharing/BikeSharing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import statements
import pandas as pd
import numpy as np
get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import mean_squared_error,r2_score
import pathlib

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-62df743d-8390-4d49-a39a-1d2e9536473d" name="files[]" multiple disabled />
#      <output id="result-62df743d-8390-4d49-a39a-1d2e9536473d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving day.csv to day.csv
# Saving hour.csv to hour.csv
# ...

# %%
day_df = pd.read_csv('day.csv')
hour_df = pd.read_csv('hour.csv')

# %% [markdown]
# **Shape of data**

# %%
day_df.shape
# Out:
# (731, 16)

# %%
hour_df.shape
# Out:
# (17379, 17)

# %% [markdown]
# # Data Analysis

# %%
day_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
day_df.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0        1  2011-01-01       1   0  ...   0.160446     331         654   985
# 1        2  2011-01-02       1   0  ...   0.248539     131         670   801
# 2        3  2011-01-03       1   0  ...   0.248309     120        1229  1349
# 3        4  2011-01-04       1   0  ...   0.160296     108        1454  1562
# 4        5  2011-01-05       1   0  ...   0.186900      82        1518  1600
#
# [5 rows x 16 columns]

# %%
day_df.describe()
# Out:
#           instant      season  ...   registered          cnt
# count  731.000000  731.000000  ...   731.000000   731.000000
# mean   366.000000    2.496580  ...  3656.172367  4504.348837
# std    211.165812    1.110807  ...  1560.256377  1937.211452
# min      1.000000    1.000000  ...    20.000000    22.000000
# 25%    183.500000    2.000000  ...  2497.000000  3152.000000
# 50%    366.000000    3.000000  ...  3662.000000  4548.000000
# 75%    548.500000    3.000000  ...  4776.500000  5956.000000
# max    731.000000    4.000000  ...  6946.000000  8714.000000
#
# [8 rows x 15 columns]

# %%
hour_df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
hour_df.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0  ...        0.0       3          13   16
# 1        2  2011-01-01       1   0  ...        0.0       8          32   40
# 2        3  2011-01-01       1   0  ...        0.0       5          27   32
# 3        4  2011-01-01       1   0  ...        0.0       3          10   13
# 4        5  2011-01-01       1   0  ...        0.0       0           1    1
#
# [5 rows x 17 columns]

# %%
hour_df.describe()
# Out:
#           instant        season  ...    registered           cnt
# count  17379.0000  17379.000000  ...  17379.000000  17379.000000
# mean    8690.0000      2.501640  ...    153.786869    189.463088
# std     5017.0295      1.106918  ...    151.357286    181.387599
# min        1.0000      1.000000  ...      0.000000      1.000000
# 25%     4345.5000      2.000000  ...     34.000000     40.000000
# 50%     8690.0000      3.000000  ...    115.000000    142.000000
# 75%    13034.5000      3.000000  ...    220.000000    281.000000
# max    17379.0000      4.000000  ...    886.000000    977.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# #### Heat Map for day data and hour data

# %%
day_correlation = day_df.corr()
day_correlation
plt.figure(figsize=(15,10))
sns.heatmap(day_correlation,annot=True)
plt.show()

# %%
hour_correlation = hour_df.corr()
hour_correlation
plt.figure(figsize=(15,10))
sns.heatmap(hour_correlation,annot=True)
plt.show()

# %%
hour_df.holiday.value_counts()
# Out:
# 0    16879
# 1      500
# Name: holiday, dtype: int64

# %%
for each_feature in ["mnth","temp","atemp","hum" ,"windspeed","casual","registered"]:
    plt.scatter(ts_day_df[each_feature],ts_day_df.cnt,color="blue")
    plt.xlabel(each_feature,fontsize=14)
    plt.ylabel("Count",fontsize=14)
    plt.show()

# %%
day_df.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# ##  Linear Regression

# %%
X_train,X_test,Y_train,Y_test =  train_test_split(day_df[['temp','atemp','hum','windspeed','casual','registered']],day_df['cnt'],test_size=0.33,random_state=19)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction=model.predict(X_test)

# %%
mse = mean_squared_error(Y_test,prediction)
print("mean squared error:",mse)
rmse = np.sqrt(mse)
print("rmse:",rmse)
# Out:
# mean squared error: 1.3339484046813233e-24
# rmse: 1.1549668413774152e-12

# %% [markdown]
# **Regression Score (R^2 (coefficient of determination**

# %%
rsquared_score = r2_score(Y_test,prediction)
print("r2_score:",rsquared_score)
# Out:
# r2_score: 1.0

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': prediction})
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# **Actual and  Predicted count**

# %%
y = [x for x in range(0,242,1)]
fig = plt.figure()
plt.plot(y,Y_test, color="blue", linewidth=2.5,)
plt.plot(y,prediction, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)             
plt.xlabel('Index', fontsize=18)                              
plt.ylabel('PRICE', fontsize=16)
# Out:
# Text(0, 0.5, 'PRICE')
